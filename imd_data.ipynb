# %% [markdown]
# <a href="https://colab.research.google.com/github/roy-sib2002/github-pages/blob/main/imd_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install xarray netCDF4 numpy pandas
# Out:
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (2025.1.2)
# Collecting netCDF4
#   Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from xarray) (24.2)
# Collecting cftime (from netCDF4)
#   Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from netCDF4) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 51.3 MB/s eta 0:00:00
# Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.3 MB/s eta 0:00:00
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.4.post1 netCDF4-1.7.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import xarray as xr
import os
import glob
import re

# Update nlat and nlon to 31
nlat, nlon = 31, 31

# Adjust latitude and longitude ranges
lats = np.linspace(7.5, 37.5, nlat)
lons = np.linspace(67.5, 97.5, nlon)

data_dir = '/content/drive/MyDrive/Colab Notebooks/tmax_data'
file_paths = sorted(glob.glob(data_dir + "/Maxtemp_MaxT_*.GRD"))

all_data = []
all_dates = []

for file_path in file_paths:
  filename = os.path.basename(file_path)

  match = re.search(r'(\d{4})', filename)
  if not match:
    print(f"Year not found in the file name: {filename}")
    continue

  year = int(match.group(1))
  ndays = 366 if pd.Timestamp(f"{year}-12-31").is_leap_year else 365

  print(f"reading: {filename} ({ndays} days)")

  raw = np.fromfile(file_path, dtype=np.float32)
  print(f"Raw data shape before reshape: {raw.shape}")  # Print raw data shape
  expected_shape = (ndays, nlat, nlon)
  print(f"Expected data shape: {expected_shape}")  # Print expected shape

  # Calculate the expected number of elements
  expected_elements = ndays * nlat * nlon

  # Check if the raw data size matches the expected size
  if raw.size != expected_elements:
      print(f"Reshape failed for {filename}. Raw data size ({raw.size}) does not match expected size ({expected_elements}). Skipping.")
      continue  # Skip to the next file

  try:
    data = raw.reshape(expected_shape)
  except ValueError:
    print(f"Reshape failed for {filename}. Skipping.")
    print(f"Raw data shape: {raw.shape}")
    continue

  dates = pd.date_range(start=f"{year}-01-01", periods=ndays)
  all_data.append(data)
  all_dates.extend(dates)

if len(all_data) == 0:
  raise ValueError("No valid GRD files were successfully read.")

all_data_array = np.concatenate(all_data, axis=0)

ds = xr.Dataset(
    {
        'tmax': (['time', 'lat', 'lon'], all_data_array)
    },
    coords={
        'time': all_dates,
        'lat': lats,
        'lon': lons
    },
    attrs={
        'title': 'Daily Tmax from IMD files(1951-2024)',
        'description': 'Converted from .GRD to NetCDF',
        'source': 'IMD',
        'resolution': '1.0 X 1.0'
    }
)

output_path = '/content/drive/MyDrive/Colab Notebooks/tmax_IMD_1951_2024.nc'
ds.to_netcdf(output_path)
print(f"NetCDF files have been saved successfully at: \n{output_path}")
# Out:
# reading: Maxtemp_MaxT_1951.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1952.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1953.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1954.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1955.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1956.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1957.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1958.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1959.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1960.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1961.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1962.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1963.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1964.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1965.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1966.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1967.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1968.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1969.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1970.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1971.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1972.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1973.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1974.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1975.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1976.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1977.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1978.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1979.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1980.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1981.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1982.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1983.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1984.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1985.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1986.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1987.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1988.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1989.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1990.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1991.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1992.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1993.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1994.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1995.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1996.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_1997.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1998.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_1999.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2000.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_2001.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2002.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2003.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2004.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_2005.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2006.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2007.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2008.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_2009.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2010.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2011.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2012.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_2013.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2014.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2015.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2016.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_2017.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2018.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2019.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2020.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# reading: Maxtemp_MaxT_2021.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2022.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2023.GRD (365 days)
# Raw data shape before reshape: (350765,)
# Expected data shape: (365, 31, 31)
# reading: Maxtemp_MaxT_2024.GRD (366 days)
# Raw data shape before reshape: (351726,)
# Expected data shape: (366, 31, 31)
# NetCDF files have been saved successfully at:
# /content/drive/MyDrive/Colab Notebooks/tmax_IMD_1951_2024.nc

# %%
import os
data_dir = '/content/drive/MyDrive/Colab Notebooks/tmax_data'
files = os.listdir(data_dir)
print(files)
test_file = os.path.join(data_dir, 'Maxtemp_MaxT_1986.GRD')

if os.path.exists(test_file):
    print("✅ File exists: Maxtemp_MaxT_1986.GRD")
else:
    print("❌ File not found: Maxtemp_MaxT_1986.GRD")
# Out:
# ['Maxtemp_MaxT_2019.GRD', 'Maxtemp_MaxT_2018.GRD', 'Maxtemp_MaxT_2017.GRD', 'Maxtemp_MaxT_2016.GRD', 'Maxtemp_MaxT_2015.GRD', 'Maxtemp_MaxT_2014.GRD', 'Maxtemp_MaxT_2013.GRD', 'Maxtemp_MaxT_2012.GRD', 'Maxtemp_MaxT_2011.GRD', 'Maxtemp_MaxT_2010.GRD', 'Maxtemp_MaxT_2024.GRD', 'Maxtemp_MaxT_2023.GRD', 'Maxtemp_MaxT_2022.GRD', 'Maxtemp_MaxT_2021.GRD', 'Maxtemp_MaxT_2020.GRD', 'Maxtemp_MaxT_1953.GRD', 'Maxtemp_MaxT_1952.GRD', 'Maxtemp_MaxT_1954.GRD', 'Maxtemp_MaxT_1951.GRD', 'Maxtemp_MaxT_1968.GRD', 'Maxtemp_MaxT_1959.GRD', 'Maxtemp_MaxT_1963.GRD', 'Maxtemp_MaxT_1972.GRD', 'Maxtemp_MaxT_1982.GRD', 'Maxtemp_MaxT_1973.GRD', 'Maxtemp_MaxT_1975.GRD', 'Maxtemp_MaxT_1958.GRD', 'Maxtemp_MaxT_1977.GRD', 'Maxtemp_MaxT_1967.GRD', 'Maxtemp_MaxT_1971.GRD', 'Maxtemp_MaxT_1979.GRD', 'Maxtemp_MaxT_1981.GRD', 'Maxtemp_MaxT_1966.GRD', 'Maxtemp_MaxT_1957.GRD', 'Maxtemp_MaxT_1955.GRD', 'Maxtemp_MaxT_1978.GRD', 'Maxtemp_MaxT_1970.GRD', 'Maxtemp_MaxT_1961.GRD', 'Maxtemp_MaxT_1969.GRD', 'Maxtemp_MaxT_1956.GRD', 'Maxtemp_MaxT_1965.GRD', 'Maxtemp_MaxT_1964.GRD', 'Maxtemp_MaxT_1974.GRD', 'Maxtemp_MaxT_1960.GRD', 'Maxtemp_MaxT_1962.GRD', 'Maxtemp_MaxT_1980.GRD', 'Maxtemp_MaxT_1976.GRD', 'Maxtemp_MaxT_1996.GRD', 'Maxtemp_MaxT_1995.GRD', 'Maxtemp_MaxT_1998.GRD', 'Maxtemp_MaxT_1994.GRD', 'Maxtemp_MaxT_1985.GRD', 'Maxtemp_MaxT_1988.GRD', 'Maxtemp_MaxT_2001.GRD', 'Maxtemp_MaxT_2003.GRD', 'Maxtemp_MaxT_1986.GRD', 'Maxtemp_MaxT_1999.GRD', 'Maxtemp_MaxT_1983.GRD', 'Maxtemp_MaxT_1992.GRD', 'Maxtemp_MaxT_1993.GRD', 'Maxtemp_MaxT_1991.GRD', 'Maxtemp_MaxT_2002.GRD', 'Maxtemp_MaxT_2000.GRD', 'Maxtemp_MaxT_1997.GRD', 'Maxtemp_MaxT_2004.GRD', 'Maxtemp_MaxT_1984.GRD', 'Maxtemp_MaxT_1987.GRD', 'Maxtemp_MaxT_1989.GRD', 'Maxtemp_MaxT_2005.GRD', 'Maxtemp_MaxT_1990.GRD', 'Maxtemp_MaxT_2007.GRD', 'Maxtemp_MaxT_2008.GRD', 'Maxtemp_MaxT_2009.GRD', 'Maxtemp_MaxT_2006.GRD']
# ✅ File exists: Maxtemp_MaxT_1986.GRD

# %%
import glob

file_paths = sorted(glob.glob(data_dir + "/Maxtemp_MaxT_*.GRD"))

print("📂 Found files:")
for f in file_paths[:5]:  # show only first 5
    print(f)
print(f"Total found: {len(file_paths)}")
# Out:
# 📂 Found files:
# /content/drive/MyDrive/Colab Notebooks/tmax_data/Maxtemp_MaxT_1951.GRD
# /content/drive/MyDrive/Colab Notebooks/tmax_data/Maxtemp_MaxT_1952.GRD
# /content/drive/MyDrive/Colab Notebooks/tmax_data/Maxtemp_MaxT_1953.GRD
# /content/drive/MyDrive/Colab Notebooks/tmax_data/Maxtemp_MaxT_1954.GRD
# /content/drive/MyDrive/Colab Notebooks/tmax_data/Maxtemp_MaxT_1955.GRD
# Total found: 74

# %%
import numpy as np
import pandas as pd
import xarray as xr
import os
import glob
import re

# Grid dimensions and ranges
nlat, nlon = 31, 31
lats = np.linspace(7.5, 37.5, nlat)
lons = np.linspace(67.5, 97.5, nlon)

# Data and output directories
data_dir = '/content/drive/MyDrive/Colab Notebooks/tmax_data'
output_dir = os.path.join(data_dir, 'new_saved_folder')  # Create output directory path

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

file_paths = sorted(glob.glob(data_dir + "/Maxtemp_MaxT_*.GRD"))

for file_path in file_paths:
    filename = os.path.basename(file_path)
    match = re.search(r'(\d{4})', filename)
    if not match:
        print(f"Year not found in the file name: {filename}")
        continue

    year = int(match.group(1))
    ndays = 366 if pd.Timestamp(f"{year}-12-31").is_leap_year else 365

    print(f"reading: {filename} ({ndays} days)")

    raw = np.fromfile(file_path, dtype=np.float32)
    expected_shape = (ndays, nlat, nlon)
    expected_elements = ndays * nlat * nlon

    if raw.size != expected_elements:
        print(f"Reshape failed for {filename}. Raw data size ({raw.size}) does not match expected size ({expected_elements}). Skipping.")
        continue

    try:
        data = raw.reshape(expected_shape)
    except ValueError:
        print(f"Reshape failed for {filename}. Skipping.")
        continue

    dates = pd.date_range(start=f"{year}-01-01", periods=ndays)

    ds = xr.Dataset(
        {
            'tmax': (['time', 'lat', 'lon'], data)
        },
        coords={
            'time': dates,
            'lat': lats,
            'lon': lons
        },
        attrs={
            'title': f'Daily Tmax from IMD file ({year})',
            'description': 'Converted from .GRD to NetCDF',
            'source': 'IMD',
            'resolution': '1.0 X 1.0'
        }
    )

    # Create output file path with year in the filename
    output_path = os.path.join(output_dir, f"tmax_IMD_{year}.nc")
    ds.to_netcdf(output_path)
    print(f"NetCDF file saved: {output_path}")

print("All NetCDF files have been saved successfully in 'new_saved_folder'.")
# Out:
# reading: Maxtemp_MaxT_1951.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1951.nc
# reading: Maxtemp_MaxT_1952.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1952.nc
# reading: Maxtemp_MaxT_1953.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1953.nc
# reading: Maxtemp_MaxT_1954.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1954.nc
# reading: Maxtemp_MaxT_1955.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1955.nc
# reading: Maxtemp_MaxT_1956.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1956.nc
# reading: Maxtemp_MaxT_1957.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1957.nc
# reading: Maxtemp_MaxT_1958.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1958.nc
# reading: Maxtemp_MaxT_1959.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1959.nc
# reading: Maxtemp_MaxT_1960.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1960.nc
# reading: Maxtemp_MaxT_1961.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1961.nc
# reading: Maxtemp_MaxT_1962.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1962.nc
# reading: Maxtemp_MaxT_1963.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1963.nc
# reading: Maxtemp_MaxT_1964.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1964.nc
# reading: Maxtemp_MaxT_1965.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1965.nc
# reading: Maxtemp_MaxT_1966.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1966.nc
# reading: Maxtemp_MaxT_1967.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1967.nc
# reading: Maxtemp_MaxT_1968.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1968.nc
# reading: Maxtemp_MaxT_1969.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1969.nc
# reading: Maxtemp_MaxT_1970.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1970.nc
# reading: Maxtemp_MaxT_1971.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1971.nc
# reading: Maxtemp_MaxT_1972.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1972.nc
# reading: Maxtemp_MaxT_1973.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1973.nc
# reading: Maxtemp_MaxT_1974.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1974.nc
# reading: Maxtemp_MaxT_1975.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1975.nc
# reading: Maxtemp_MaxT_1976.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1976.nc
# reading: Maxtemp_MaxT_1977.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1977.nc
# reading: Maxtemp_MaxT_1978.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1978.nc
# reading: Maxtemp_MaxT_1979.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1979.nc
# reading: Maxtemp_MaxT_1980.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1980.nc
# reading: Maxtemp_MaxT_1981.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1981.nc
# reading: Maxtemp_MaxT_1982.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1982.nc
# reading: Maxtemp_MaxT_1983.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1983.nc
# reading: Maxtemp_MaxT_1984.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1984.nc
# reading: Maxtemp_MaxT_1985.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1985.nc
# reading: Maxtemp_MaxT_1986.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1986.nc
# reading: Maxtemp_MaxT_1987.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1987.nc
# reading: Maxtemp_MaxT_1988.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1988.nc
# reading: Maxtemp_MaxT_1989.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1989.nc
# reading: Maxtemp_MaxT_1990.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1990.nc
# reading: Maxtemp_MaxT_1991.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1991.nc
# reading: Maxtemp_MaxT_1992.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1992.nc
# reading: Maxtemp_MaxT_1993.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1993.nc
# reading: Maxtemp_MaxT_1994.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1994.nc
# reading: Maxtemp_MaxT_1995.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1995.nc
# reading: Maxtemp_MaxT_1996.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1996.nc
# reading: Maxtemp_MaxT_1997.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1997.nc
# reading: Maxtemp_MaxT_1998.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1998.nc
# reading: Maxtemp_MaxT_1999.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_1999.nc
# reading: Maxtemp_MaxT_2000.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2000.nc
# reading: Maxtemp_MaxT_2001.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2001.nc
# reading: Maxtemp_MaxT_2002.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2002.nc
# reading: Maxtemp_MaxT_2003.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2003.nc
# reading: Maxtemp_MaxT_2004.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2004.nc
# reading: Maxtemp_MaxT_2005.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2005.nc
# reading: Maxtemp_MaxT_2006.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2006.nc
# reading: Maxtemp_MaxT_2007.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2007.nc
# reading: Maxtemp_MaxT_2008.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2008.nc
# reading: Maxtemp_MaxT_2009.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2009.nc
# reading: Maxtemp_MaxT_2010.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2010.nc
# reading: Maxtemp_MaxT_2011.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2011.nc
# reading: Maxtemp_MaxT_2012.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2012.nc
# reading: Maxtemp_MaxT_2013.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2013.nc
# reading: Maxtemp_MaxT_2014.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2014.nc
# reading: Maxtemp_MaxT_2015.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2015.nc
# reading: Maxtemp_MaxT_2016.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2016.nc
# reading: Maxtemp_MaxT_2017.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2017.nc
# reading: Maxtemp_MaxT_2018.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2018.nc
# reading: Maxtemp_MaxT_2019.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2019.nc
# reading: Maxtemp_MaxT_2020.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2020.nc
# reading: Maxtemp_MaxT_2021.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2021.nc
# reading: Maxtemp_MaxT_2022.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2022.nc
# reading: Maxtemp_MaxT_2023.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2023.nc
# reading: Maxtemp_MaxT_2024.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/tmax_data/new_saved_folder/tmax_IMD_2024.nc
# All NetCDF files have been saved successfully in 'new_saved_folder'.

# %%
import numpy as np
import pandas as pd
import xarray as xr
import os
import glob
import re

# Grid dimensions and ranges
nlat, nlon = 31, 31
lats = np.linspace(7.5, 37.5, nlat)
lons = np.linspace(67.5, 97.5, nlon)

# Data and output directories
data_dir = '/content/drive/MyDrive/Colab Notebooks/tmax_data'
output_dir = '/content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp'  # Updated output directory

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

file_paths = sorted(glob.glob(data_dir + "/Maxtemp_MaxT_*.GRD"))

for file_path in file_paths:
    filename = os.path.basename(file_path)
    match = re.search(r'(\d{4})', filename)
    if not match:
        print(f"Year not found in the file name: {filename}")
        continue

    year = int(match.group(1))
    ndays = 366 if pd.Timestamp(f"{year}-12-31").is_leap_year else 365

    print(f"reading: {filename} ({ndays} days)")

    raw = np.fromfile(file_path, dtype=np.float32)
    expected_shape = (ndays, nlat, nlon)
    expected_elements = ndays * nlat * nlon

    if raw.size != expected_elements:
        print(f"Reshape failed for {filename}. Raw data size ({raw.size}) does not match expected size ({expected_elements}). Skipping.")
        continue

    try:
        data = raw.reshape(expected_shape)
    except ValueError:
        print(f"Reshape failed for {filename}. Skipping.")
        continue

    dates = pd.date_range(start=f"{year}-01-01", periods=ndays)

    ds = xr.Dataset(
        {
            'tmax': (['time', 'lat', 'lon'], data)
        },
        coords={
            'time': dates,
            'lat': lats,
            'lon': lons
        },
        attrs={
            'title': f'Daily Tmax from IMD file ({year})',
            'description': 'Converted from .GRD to NetCDF',
            'source': 'IMD',
            'resolution': '1.0 X 1.0'
        }
    )

    # Create output file path with year in the filename
    output_path = os.path.join(output_dir, f"tmax_IMD_{year}.nc")
    ds.to_netcdf(output_path)
    print(f"NetCDF file saved: {output_path}")

print("All NetCDF files have been saved successfully in 'new_updated_imd_temp'.")
# Out:
# reading: Maxtemp_MaxT_1951.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1951.nc
# reading: Maxtemp_MaxT_1952.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1952.nc
# reading: Maxtemp_MaxT_1953.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1953.nc
# reading: Maxtemp_MaxT_1954.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1954.nc
# reading: Maxtemp_MaxT_1955.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1955.nc
# reading: Maxtemp_MaxT_1956.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1956.nc
# reading: Maxtemp_MaxT_1957.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1957.nc
# reading: Maxtemp_MaxT_1958.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1958.nc
# reading: Maxtemp_MaxT_1959.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1959.nc
# reading: Maxtemp_MaxT_1960.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1960.nc
# reading: Maxtemp_MaxT_1961.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1961.nc
# reading: Maxtemp_MaxT_1962.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1962.nc
# reading: Maxtemp_MaxT_1963.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1963.nc
# reading: Maxtemp_MaxT_1964.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1964.nc
# reading: Maxtemp_MaxT_1965.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1965.nc
# reading: Maxtemp_MaxT_1966.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1966.nc
# reading: Maxtemp_MaxT_1967.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1967.nc
# reading: Maxtemp_MaxT_1968.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1968.nc
# reading: Maxtemp_MaxT_1969.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1969.nc
# reading: Maxtemp_MaxT_1970.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1970.nc
# reading: Maxtemp_MaxT_1971.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1971.nc
# reading: Maxtemp_MaxT_1972.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1972.nc
# reading: Maxtemp_MaxT_1973.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1973.nc
# reading: Maxtemp_MaxT_1974.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1974.nc
# reading: Maxtemp_MaxT_1975.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1975.nc
# reading: Maxtemp_MaxT_1976.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1976.nc
# reading: Maxtemp_MaxT_1977.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1977.nc
# reading: Maxtemp_MaxT_1978.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1978.nc
# reading: Maxtemp_MaxT_1979.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1979.nc
# reading: Maxtemp_MaxT_1980.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1980.nc
# reading: Maxtemp_MaxT_1981.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1981.nc
# reading: Maxtemp_MaxT_1982.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1982.nc
# reading: Maxtemp_MaxT_1983.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1983.nc
# reading: Maxtemp_MaxT_1984.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1984.nc
# reading: Maxtemp_MaxT_1985.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1985.nc
# reading: Maxtemp_MaxT_1986.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1986.nc
# reading: Maxtemp_MaxT_1987.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1987.nc
# reading: Maxtemp_MaxT_1988.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1988.nc
# reading: Maxtemp_MaxT_1989.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1989.nc
# reading: Maxtemp_MaxT_1990.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1990.nc
# reading: Maxtemp_MaxT_1991.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1991.nc
# reading: Maxtemp_MaxT_1992.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1992.nc
# reading: Maxtemp_MaxT_1993.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1993.nc
# reading: Maxtemp_MaxT_1994.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1994.nc
# reading: Maxtemp_MaxT_1995.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1995.nc
# reading: Maxtemp_MaxT_1996.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1996.nc
# reading: Maxtemp_MaxT_1997.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1997.nc
# reading: Maxtemp_MaxT_1998.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1998.nc
# reading: Maxtemp_MaxT_1999.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_1999.nc
# reading: Maxtemp_MaxT_2000.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2000.nc
# reading: Maxtemp_MaxT_2001.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2001.nc
# reading: Maxtemp_MaxT_2002.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2002.nc
# reading: Maxtemp_MaxT_2003.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2003.nc
# reading: Maxtemp_MaxT_2004.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2004.nc
# reading: Maxtemp_MaxT_2005.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2005.nc
# reading: Maxtemp_MaxT_2006.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2006.nc
# reading: Maxtemp_MaxT_2007.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2007.nc
# reading: Maxtemp_MaxT_2008.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2008.nc
# reading: Maxtemp_MaxT_2009.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2009.nc
# reading: Maxtemp_MaxT_2010.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2010.nc
# reading: Maxtemp_MaxT_2011.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2011.nc
# reading: Maxtemp_MaxT_2012.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2012.nc
# reading: Maxtemp_MaxT_2013.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2013.nc
# reading: Maxtemp_MaxT_2014.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2014.nc
# reading: Maxtemp_MaxT_2015.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2015.nc
# reading: Maxtemp_MaxT_2016.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2016.nc
# reading: Maxtemp_MaxT_2017.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2017.nc
# reading: Maxtemp_MaxT_2018.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2018.nc
# reading: Maxtemp_MaxT_2019.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2019.nc
# reading: Maxtemp_MaxT_2020.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2020.nc
# reading: Maxtemp_MaxT_2021.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2021.nc
# reading: Maxtemp_MaxT_2022.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2022.nc
# reading: Maxtemp_MaxT_2023.GRD (365 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2023.nc
# reading: Maxtemp_MaxT_2024.GRD (366 days)
# NetCDF file saved: /content/drive/MyDrive/Colab Notebooks/new_updated_imd_temp/tmax_IMD_2024.nc
# All NetCDF files have been saved successfully in 'new_updated_imd_temp'.
